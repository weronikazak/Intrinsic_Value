# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import os
import pandas as pd
import yfinance as yf

# %%
tsla = yf.Ticker("TSLA")

# %%
i = tsla.info
i
# Out:
# {'zip': '78725',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 99290,
# ...

# %%
f = tsla.financials
f
# Out:
#                                         2021-12-31  2020-12-31  2019-12-31  \
# Research Development                     2.593e+09   1.491e+09   1.343e+09
# Effect Of Accounting Charges                  None        None        None
# Income Before Tax                        6.343e+09   1.154e+09   -6.65e+08
# Minority Interest                        1.394e+09   1.454e+09   1.492e+09
# Net Income                               5.519e+09    7.21e+08   -8.62e+08
# Selling General Administrative           4.517e+09   3.188e+09   2.646e+09
# Gross Profit                            1.3606e+10    6.63e+09   4.069e+09
# Ebit                                     6.523e+09   1.951e+09       8e+07
# Operating Income                         6.523e+09   1.951e+09       8e+07
# Other Operating Expenses                  -2.7e+07    -2.7e+07    -2.7e+07
# Interest Expense                         -3.58e+08   -7.84e+08   -7.25e+08
# ...

# %%
i["marketCap"] + i['totalDebt'] +
